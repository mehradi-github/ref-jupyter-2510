# %%
import numpy as np

# %%
x=np.array([1,2,3,4])
y= np.array([7,8])

# %%
a,b= np.meshgrid(x,y)
a
# Out:
# array([[1, 2, 3, 4],
#        [1, 2, 3, 4]])

# %%
b
# Out:
# array([[7, 7, 7, 7],
#        [8, 8, 8, 8]])
