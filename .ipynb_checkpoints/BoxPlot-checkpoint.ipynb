# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data=np.array([-20,-3,-2,-1,0,1,2,3,4,5,8,9,10,11,12,13,14,15,16,19,40,50])

# %%
q1=np.quantile(data, .25)
q1
# Out:
# np.float64(1.25)

# %%
q2=np.quantile(data, .5)
q2
# Out:
# np.float64(8.5)

# %%
q3=np.quantile(data, .75)
q3
# Out:
# np.float64(13.75)

# %%
iqr=q3-q1
iqr
# Out:
# np.float64(12.5)

# %%
lv=q1-1.5*iqr
lv
# Out:
# np.float64(-17.5)

# %%
hv=q3+1.5*iqr
hv
# Out:
# np.float64(32.5)

# %%
plt=plt.boxplot(data)

# %%
class1= np.array([60,70,80,83,85,87,88,89,90,92,94,95,97,100,110])

# %%
class2=np.array([130,143,150,158,160,170,175,182,188,190,200,210,280,300])

# %%
plt.boxplot([class1,class2],patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x76904da49f90>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x76904da4a210>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x76904da49e50>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x76904da4a490>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x76904da4a5d0>,
# ...
#  'means': []}

# %%
grade=['A','B','C','D','E']

# %%
n=[5,10,8,3,2]

# %%
k=[0,1,2,3,4]

# %%
plt.bar(k,n,color='green')
plt.xlabel('Grade')
plt.ylabel('No of student')
a=plt.xticks(k,grade)

# %%
x1=np.array([-3,-2,-1,0,1,2,3])

# %%
y1=np.array([9,4,1,0,1,4,9])

# %%
plt.scatter(x1,y1, c='r')

# %%
data2=np.array([3,3,5,6,7,7,8,9,9,10,10,10,11,12,12,14,15,16,17,18,19,19,20])

# %%
plt.hist(data2,bins='auto',edgecolor='black')
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
data3=100+15*np.random.rand(1000)

# %%
import matplotlib.mlab as mlab

# %%
n,bins3,_=plt.hist(data3,bins='auto',edgecolor='black')
y3=mlab.normpdf(bins3,100,15)
plt.plot(bins,y3,'r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[67], line 2
#       1 n,bins3,_=plt.hist(data3,bins='auto',edgecolor='black')
# ----> 2 y3=mlab.normpdf(bins3,100,15)
#       3 plt.plot(bins,y3,'r')
#
# AttributeError: module 'matplotlib.mlab' has no attribute 'normpdf'
